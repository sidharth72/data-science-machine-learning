# %%
import pandas as pd
import numpy as np

df = pd.read_csv('E:/DS_and_ML/datasets/weight-height.csv')

df['Gender_labels'] = df['Gender'].astype('category').cat.codes

# %%
df = df.drop('Gender', axis = 1)

# %%
df.head(5)
# Out:
#       Height      Weight  Gender_labels
# 0  73.847017  241.893563              1
# 1  68.781904  162.310473              1
# 2  74.110105  212.740856              1
# 3  71.730978  220.042470              1
# 4  69.881796  206.349801              1

# %%
from sklearn.model_selection import train_test_split

X = df.drop('Height', axis=1)
y = df['Height']

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.3, random_state = 42)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
y_train = np.array(y_train)

y_train = y_train.reshape(-1,1)

y_train
# Out:
# array([[63.48570167],
#        [71.17286856],
#        [62.02116348],
#        ...,
#        [64.3254058 ],
#        [69.07449203],
#        [67.58883983]])

# %%
def Gradient_Descent(X,y):
    m = b = 0
    iteration = 200
    learning_rate = 0.02
    n = len(X)
    
    
    for i in range(iteration):
        y_pred = m * X + b
        cost = (1/n)*sum([val**2 for val in (y-y_pred)])
        md = -(2/n) * sum(X*(y - y_pred))
        bd = -(2/n) * sum(y - y_pred)
        m = m - learning_rate * md
        b = b - learning_rate * bd
        
        print("M:{}, B:{}, COST:{}, Predicitons:{}".format(m[0], b[0], cost[0], y_pred[0]))

Gradient_Descent(X_train, y_train)
# Out:
# M:0.14212539458887566, B:2.6528105109165, COST:4413.160829124425, Predicitons:[0. 0.]
# M:0.2785657733941963, B:5.199508601396339, COST:4067.3382706282387, Predicitons:[2.51089943 2.54825323]
# M:0.409548537047304, B:7.644338768256988, COST:3748.6282007181476, Predicitons:[4.92136287 4.99457633]
# M:0.5352919901542876, B:9.991375728443208, COST:3454.905000289013, Predicitons:[7.23540779 7.3430465 ]
# M:0.656005705136992, B:12.244531210221972, COST:3184.209698773518, Predicitons:[9.4568909  9.59757787]
# M:0.7718908715203888, B:14.407560472729603, COST:2934.7369088968285, Predicitons:[11.58951469 11.76192799]
# M:0.8831406312484495, B:16.484068564736926, COST:2704.822785746486, Predicitons:[13.63683353 13.8397041 ]
# M:0.9899404005873875, B:18.477516333063942, COST:2492.93392985114, Predicitons:[15.60225961 15.83436916]
# M:1.0924681791527684, B:20.391226190657886, COST:2297.6571602579543, Predicitons:[17.48906865 17.74924762]
# ...

# %%
X = scaler.fit_transform(X)
y = np.array(y)

y = y.reshape(-1,1)
X_b = np.c_[np.ones((10000,1)), X]

# %%
# mx + b 
theta_best = np.linalg.inv(X_b.T.dot(X_b)).dot(X_b.T).dot(y)

# %%
theta_best
# Out:
# array([[66.36755975],
#        [ 3.94141617],
#        [-0.48143213]])

# %%
y_predict = X_b.dot(theta_best)

# %%
y_predict
# Out:
# array([[75.76251635],
#        [65.99294252],
#        [72.18374695],
#        ...,
#        [62.80222302],
#        [67.14510043],
#        [60.98216538]])

# %%
from sklearn.metrics import mean_squared_error

mse = mean_squared_error(y_predict, y)

print("MSE:", mse)
# Out:
# MSE: 2.059057879331962

# %%
def SGD(X,y):
    m,b = np.random.rand(2,1)
    iteration = 300
    learning_rate = 0.1
    n = len(X)
    
    for i in range(iteration):
        y_pred = m * X + b
        cost = (1/n)*sum([val**2 for val in (y-y_pred)])
        md = -(2/n) * sum(X*(y - y_pred))
        bd = -(2/n) * sum(y - y_pred)
        m = m - learning_rate * md
        b = b - learning_rate * bd
        
        
    #plt.scatter(m_arr, b_arr)
        
    
        
        print("M:{}, B:{}, iter:{}, cost:{} pred:{}".format(m,b,i,cost, y_pred[0]))

# %%
SGD(X_train, y_train)
# Out:
# M:[1.27783897 1.09555453], B:[13.54354155 13.54354155], iter:0, cost:[4362.40767339 4363.7000974 ] pred:[-0.35858463 -0.35219765]
# M:[1.73289815 1.40478616], B:[24.0988858 24.0988858], iter:1, cost:[2792.71808167 2795.57783679] pred:[12.26762942 12.45950802]
# M:[2.09694549 1.65217146], B:[32.54316119 32.54316119], iter:2, cost:[1788.11674296 1791.97959   ] pred:[22.36860067 22.70887256]
# M:[2.38818337 1.8500797 ], B:[39.29858151 39.29858151], iter:3, cost:[1145.17188619 1149.67671205] pred:[30.44937766 30.90836419]
# M:[2.62117367 2.00840629], B:[44.70291776 44.70291776], iter:4, cost:[733.68717786 738.60287017] pred:[36.91399926 37.4679575 ]
# M:[2.80756591 2.13506757], B:[49.02638676 49.02638676], iter:5, cost:[470.33696453 475.51561136] pred:[42.08569654 42.71563214]
# M:[2.9566797  2.23639659], B:[52.48516197 52.48516197], iter:6, cost:[301.79282799 307.13976573] pred:[46.22305436 46.91377186]
# ...
